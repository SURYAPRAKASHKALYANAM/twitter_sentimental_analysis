# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('iraq_iran_earthquake.csv')

# %%
df
# Out:
#                                                  Tweet  Label
# 0    RT @PressTV: UPDATE: Death toll from Iran’s qu...      1
# 1    RT @CAFOD: We pray for all those affected by t...      0
# 2    RT @ReutersWorld: JUST IN: Death toll reaches ...      1
# 3    RT @LaylaAlhussein: A magnitude 7.2 earthquake...      1
# 4    RT @LaylaAlhussein: A magnitude 7.2 earthquake...      1
# ..                                                 ...    ...
# 592  Damage proxy maps of 5 cities near the epicent...      1
# 593  #Iran Daily: US Treasury Blocks Donations for ...      1
# 594  #Kurdish children's situation after the #earth...      1
# 595  #IRAN'S #EARTHQUAKE EXPOSES #POLITICAL RIFTS A...      1
# 596  Victims of last week's earthquake gather outdo...      1
#
# [597 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Tweet    0
# Label    0
# dtype: int64

# %%
def lower(x):
    return x.lower()
df['Tweet']=df['Tweet'].apply(lower)

# %%
df
# Out:
#                                                  Tweet  Label
# 0    rt @presstv: update: death toll from iran’s qu...      1
# 1    rt @cafod: we pray for all those affected by t...      0
# 2    rt @reutersworld: just in: death toll reaches ...      1
# 3    rt @laylaalhussein: a magnitude 7.2 earthquake...      1
# 4    rt @laylaalhussein: a magnitude 7.2 earthquake...      1
# ..                                                 ...    ...
# 592  damage proxy maps of 5 cities near the epicent...      1
# 593  #iran daily: us treasury blocks donations for ...      1
# 594  #kurdish children's situation after the #earth...      1
# 595  #iran's #earthquake exposes #political rifts a...      1
# 596  victims of last week's earthquake gather outdo...      1
#
# [597 rows x 2 columns]

# %%
from emot.emo_unicode import UNICODE_EMOJI
# Function for converting emojis into word
def convert_emojis(text):
    for emot in UNICODE_EMOJI:
        text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
    return text
df['Tweet']=df['Tweet'].apply(convert_emojis)

# %%
df
# Out:
#                                                  Tweet  Label
# 0    rt @presstv: update: death toll from iran’s qu...      1
# 1    rt @cafod: we pray for all those affected by t...      0
# 2    rt @reutersworld: just in: death toll reaches ...      1
# 3    rt @laylaalhussein: a magnitude 7.2 earthquake...      1
# 4    rt @laylaalhussein: a magnitude 7.2 earthquake...      1
# ..                                                 ...    ...
# 592  damage proxy maps of 5 cities near the epicent...      1
# 593  #iran daily: us treasury blocks donations for ...      1
# 594  #kurdish children's situation after the #earth...      1
# 595  #iran's #earthquake exposes #political rifts a...      1
# 596  victims of last week's earthquake gather outdo...      1
#
# [597 rows x 2 columns]

# %%
from nltk.tokenize import word_tokenize
def tokenize(x):
    return word_tokenize(x)
df['Tweet']=df['Tweet'].apply(tokenize)

# %%
df
# Out:
#                                                  Tweet  Label
# 0    [rt, @, presstv, :, update, :, death, toll, fr...      1
# 1    [rt, @, cafod, :, we, pray, for, all, those, a...      0
# 2    [rt, @, reutersworld, :, just, in, :, death, t...      1
# 3    [rt, @, laylaalhussein, :, a, magnitude, 7.2, ...      1
# 4    [rt, @, laylaalhussein, :, a, magnitude, 7.2, ...      1
# ..                                                 ...    ...
# 592  [damage, proxy, maps, of, 5, cities, near, the...      1
# 593  [#, iran, daily, :, us, treasury, blocks, dona...      1
# 594  [#, kurdish, children, 's, situation, after, t...      1
# 595  [#, iran, 's, #, earthquake, exposes, #, polit...      1
# 596  [victims, of, last, week, 's, earthquake, gath...      1
#
# [597 rows x 2 columns]

# %%
def remove_punct(x):
    import string
    punct_tag=set(string.punctuation)
    t=[i for i in x if i not in punct_tag]
    return t
      
df['Tweet']=df['Tweet'].apply(remove_punct)

# %%
df
# Out:
#                                                  Tweet  Label
# 0    [rt, presstv, update, death, toll, from, iran,...      1
# 1    [rt, cafod, we, pray, for, all, those, affecte...      0
# 2    [rt, reutersworld, just, in, death, toll, reac...      1
# 3    [rt, laylaalhussein, a, magnitude, 7.2, earthq...      1
# 4    [rt, laylaalhussein, a, magnitude, 7.2, earthq...      1
# ..                                                 ...    ...
# 592  [damage, proxy, maps, of, 5, cities, near, the...      1
# 593  [iran, daily, us, treasury, blocks, donations,...      1
# 594  [kurdish, children, 's, situation, after, the,...      1
# 595  [iran, 's, earthquake, exposes, political, rif...      1
# 596  [victims, of, last, week, 's, earthquake, gath...      1
#
# [597 rows x 2 columns]

# %%
def whites(x):
    w={' '}
    x=[i for i in x if i not in w]
    return x
df['Tweet']=df['Tweet'].apply(whites)

# %%
df
# Out:
#                                                  Tweet  Label
# 0    [rt, presstv, update, death, toll, from, iran,...      1
# 1    [rt, cafod, we, pray, for, all, those, affecte...      0
# 2    [rt, reutersworld, just, in, death, toll, reac...      1
# 3    [rt, laylaalhussein, a, magnitude, 7.2, earthq...      1
# 4    [rt, laylaalhussein, a, magnitude, 7.2, earthq...      1
# ..                                                 ...    ...
# 592  [damage, proxy, maps, of, 5, cities, near, the...      1
# 593  [iran, daily, us, treasury, blocks, donations,...      1
# 594  [kurdish, children, 's, situation, after, the,...      1
# 595  [iran, 's, earthquake, exposes, political, rif...      1
# 596  [victims, of, last, week, 's, earthquake, gath...      1
#
# [597 rows x 2 columns]

# %%
from nltk.corpus import stopwords
import nltk
def re_stop(x):
    nltk_stopwords = nltk.corpus.stopwords.words("english")
    return [ token for token in x if token not in nltk_stopwords]
df['Tweet']=df['Tweet'].apply(re_stop)

# %%
df
# Out:
#                                                  Tweet  Label
# 0    [rt, presstv, update, death, toll, iran, ’, qu...      1
# 1    [rt, cafod, pray, affected, earthquake, iraq, ...      0
# 2    [rt, reutersworld, death, toll, reaches, 328, ...      1
# 3    [rt, laylaalhussein, magnitude, 7.2, earthquak...      1
# 4    [rt, laylaalhussein, magnitude, 7.2, earthquak...      1
# ..                                                 ...    ...
# 592  [damage, proxy, maps, 5, cities, near, epicent...      1
# 593  [iran, daily, us, treasury, blocks, donations,...      1
# 594  [kurdish, children, 's, situation, earthquake,...      1
# 595  [iran, 's, earthquake, exposes, political, rif...      1
# 596  [victims, last, week, 's, earthquake, gather, ...      1
#
# [597 rows x 2 columns]

# %%
from nltk.stem import WordNetLemmatizer
def lemm(x):
    l=[]
    for i in x:
        l.append(WordNetLemmatizer().lemmatize(i))
    return l    
df['Tweet']=df['Tweet'].apply(lemm)

# %%
df
# Out:
#                                                  Tweet  Label
# 0    [rt, presstv, update, death, toll, iran, ’, qu...      1
# 1    [rt, cafod, pray, affected, earthquake, iraq, ...      0
# 2    [rt, reutersworld, death, toll, reach, 328, ir...      1
# 3    [rt, laylaalhussein, magnitude, 7.2, earthquak...      1
# 4    [rt, laylaalhussein, magnitude, 7.2, earthquak...      1
# ..                                                 ...    ...
# 592  [damage, proxy, map, 5, city, near, epicenter,...      1
# 593  [iran, daily, u, treasury, block, donation, ea...      1
# 594  [kurdish, child, 's, situation, earthquake, ir...      1
# 595  [iran, 's, earthquake, expose, political, rift...      1
# 596  [victim, last, week, 's, earthquake, gather, o...      1
#
# [597 rows x 2 columns]

# %%
from nltk.stem.porter import PorterStemmer
def stemm(x):
    l=[]
    for i in x:
        l.append(PorterStemmer().stem(i))
    return l    
df['Tweet']=df['Tweet'].apply(stemm)

# %%
df
# Out:
#                                                  Tweet  Label
# 0    [rt, presstv, updat, death, toll, iran, ’, qua...      1
# 1    [rt, cafod, pray, affect, earthquak, iraq, ira...      0
# 2    [rt, reutersworld, death, toll, reach, 328, ir...      1
# 3    [rt, laylaalhussein, magnitud, 7.2, earthquak,...      1
# 4    [rt, laylaalhussein, magnitud, 7.2, earthquak,...      1
# ..                                                 ...    ...
# 592  [damag, proxi, map, 5, citi, near, epicent, ke...      1
# 593  [iran, daili, u, treasuri, block, donat, earth...      1
# 594  [kurdish, child, 's, situat, earthquak, iran, ...      1
# 595  [iran, 's, earthquak, expos, polit, rift, inef...      1
# 596  [victim, last, week, 's, earthquak, gather, ou...      1
#
# [597 rows x 2 columns]

# %%
def combine(x):
    return ' '.join(x)
df['Tweet']=df['Tweet'].apply(combine)

# %%
df
# Out:
#                                                  Tweet  Label
# 0    rt presstv updat death toll iran ’ quak rise 2...      1
# 1    rt cafod pray affect earthquak iraq iran http ...      0
# 2    rt reutersworld death toll reach 328 iran eart...      1
# 3    rt laylaalhussein magnitud 7.2 earthquak struc...      1
# 4    rt laylaalhussein magnitud 7.2 earthquak struc...      1
# ..                                                 ...    ...
# 592  damag proxi map 5 citi near epicent kermanshah...      1
# 593  iran daili u treasuri block donat earthquak su...      1
# 594  kurdish child 's situat earthquak iran tent ho...      1
# 595  iran 's earthquak expos polit rift ineffect go...      1
# 596  victim last week 's earthquak gather outdoor n...      1
#
# [597 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()
X=tfidf.fit_transform(df['Tweet']).toarray()

# %%
#create bow
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X_cv= cv.fit_transform(df['Tweet']).toarray()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
X_train, X_test, y_train, y_test = train_test_split(X,df['Label'], test_size=0.2,random_state=35)

# %%
from sklearn.linear_model import LogisticRegression
model_l=LogisticRegression().fit(X_train,y_train)
y_pred=model_l.predict(X_test)
score=classification_report(y_test, y_pred)
print(score)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.06      0.11        17
#            1       0.87      1.00      0.93       103
#
#     accuracy                           0.87       120
#    macro avg       0.93      0.53      0.52       120
# weighted avg       0.88      0.87      0.81       120

# %%
from sklearn.svm import SVC
rf_kn =SVC()
rf_model_kn = rf_kn.fit(X_train, y_train)
y_pred = rf_model_kn.predict(X_test)
score1=classification_report(y_test, y_pred)
print(score1)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.18      0.30        17
#            1       0.88      1.00      0.94       103
#
#     accuracy                           0.88       120
#    macro avg       0.94      0.59      0.62       120
# weighted avg       0.90      0.88      0.85       120

# %%
from sklearn.tree import DecisionTreeClassifier
rf_kn = DecisionTreeClassifier()
rf_model_kn = rf_kn.fit(X_train, y_train)
y_pred = rf_model_kn.predict(X_test)
score1=classification_report(y_test, y_pred)
print(score1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.24      0.36        17
#            1       0.89      0.99      0.94       103
#
#     accuracy                           0.88       120
#    macro avg       0.84      0.61      0.65       120
# weighted avg       0.87      0.88      0.85       120

# %%
from sklearn.ensemble import RandomForestClassifier
rf_kn = RandomForestClassifier()
rf_model_kn = rf_kn.fit(X_train, y_train)
y_pred = rf_model_kn.predict(X_test)
score1=classification_report(y_test, y_pred)
print(score1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.18      0.29        17
#            1       0.88      0.99      0.93       103
#
#     accuracy                           0.88       120
#    macro avg       0.81      0.58      0.61       120
# weighted avg       0.86      0.88      0.84       120

# %%
# from sklearn.ensemble import obl
rf_kn = RandomForestClassifier()
rf_model_kn = rf_kn.fit(X_train, y_train)
y_pred = rf_model_kn.predict(X_test)
score1=classification_report(y_test, y_pred)
print(score1)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.18      0.30        17
#            1       0.88      1.00      0.94       103
#
#     accuracy                           0.88       120
#    macro avg       0.94      0.59      0.62       120
# weighted avg       0.90      0.88      0.85       120

# %%
from sklearn.neighbors import KNeighborsClassifier
rf_kn = KNeighborsClassifier()
rf_model_kn = rf_kn.fit(X_train, y_train)
y_pred = rf_model_kn.predict(X_test)
score1=classification_report(y_test, y_pred)
print(score1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.12      0.18        17
#            1       0.87      0.97      0.92       103
#
#     accuracy                           0.85       120
#    macro avg       0.63      0.54      0.55       120
# weighted avg       0.80      0.85      0.81       120

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
score1=classification_report(y_test, y_pred)
print(score1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.35      0.38        17
#            1       0.90      0.91      0.90       103
#
#     accuracy                           0.83       120
#    macro avg       0.65      0.63      0.64       120
# weighted avg       0.83      0.83      0.83       120

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, y_train)
y_pred=xgb_model.predict(X_test)
score1=classification_report(y_test,y_pred.round())
print(score1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.24      0.31        17
#            1       0.88      0.95      0.92       103
#
#     accuracy                           0.85       120
#    macro avg       0.66      0.59      0.61       120
# weighted avg       0.82      0.85      0.83       120

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import StackingClassifier

estimator_list = [
        ("knn", KNeighborsClassifier()),
        ("svm_rbf", SVC()),
        ("dt", DecisionTreeClassifier()),
        ("rf", RandomForestClassifier()),
        ("mlp", MLPClassifier(alpha=1, max_iter=1000)),
    ]
stack_model = StackingClassifier(
        estimators=estimator_list, final_estimator=LogisticRegression()
    )
stack_model.fit(X_train, y_train)
y_pred = stack_model.predict(X_test)
score = classification_report(y_test, y_pred)
print(score)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.18      0.30        17
#            1       0.88      1.00      0.94       103
#
#     accuracy                           0.88       120
#    macro avg       0.94      0.59      0.62       120
# weighted avg       0.90      0.88      0.85       120
